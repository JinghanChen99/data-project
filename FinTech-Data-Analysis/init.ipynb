# %% [markdown]
# ## Initialization Notebook
# This is your initialization notebook.
#
# **What's this for?**
#
# You can put custom code you want us to run every time we setup your environment in here.
#
# **Awesome! Anything I should not put in here?**
#
# Please don't install `jupyter` or `jedi` packages, they would break your Deepnote environment. Also, no need to put `!pip install`s here, we already save those automatically!
#
# **I want to learn more!**
#
# Great! Just [head over to our docs](https://docs.deepnote.com/environment/custom-initialization).

# %%
# %%bash
# # If your project has a 'requirements.txt' file, we'll install it here apart from blacklisted packages that interfere with Deepnote (see above).
# if test -f requirements.txt
#   then
#     sed -i '/jedi/d;/jupyter/d;' ./requirements.txt
#     pip install -r ./requirements.txt
#   else echo "There's no requirements.txt, so nothing to install. This is the case with most projects."
# fi
# Out:
# Collecting xlrd
#   Downloading xlrd-2.0.1-py2.py3-none-any.whl (96 kB)
# Collecting openpyxl
#   Downloading openpyxl-3.0.7-py2.py3-none-any.whl (243 kB)
# Collecting bs4==0.0.1
#   Downloading bs4-0.0.1.tar.gz (1.1 kB)
# Collecting google
#   Downloading google-3.0.0-py2.py3-none-any.whl (45 kB)
# Collecting yahoo_finance==1.4.0
#   Downloading yahoo-finance-1.4.0.tar.gz (8.9 kB)
# Collecting import-ipynb
#   Downloading import-ipynb-0.1.3.tar.gz (4.0 kB)
# Collecting ipynb
#   Downloading ipynb-0.5.1-py3-none-any.whl (6.9 kB)
# Collecting cufflinks==0.17.3
#   Downloading cufflinks-0.17.3.tar.gz (81 kB)
# Collecting beautifulsoup4
#   Downloading beautifulsoup4-4.9.3-py3-none-any.whl (115 kB)
# Requirement already satisfied: pytz in /shared-libs/python3.7/py/lib/python3.7/site-packages (from yahoo_finance==1.4.0->-r ./requirements.txt (line 5)) (2021.1)
# Collecting simplejson
#   Downloading simplejson-3.17.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (129 kB)
# Requirement already satisfied: numpy>=1.9.2 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from cufflinks==0.17.3->-r ./requirements.txt (line 8)) (1.19.5)
# Requirement already satisfied: pandas>=0.19.2 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from cufflinks==0.17.3->-r ./requirements.txt (line 8)) (1.2.5)
# Requirement already satisfied: plotly>=4.1.1 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from cufflinks==0.17.3->-r ./requirements.txt (line 8)) (5.1.0)
# Requirement already satisfied: six>=1.9.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from cufflinks==0.17.3->-r ./requirements.txt (line 8)) (1.16.0)
# Collecting colorlover>=0.2.1
#   Downloading colorlover-0.3.0-py3-none-any.whl (8.9 kB)
# Requirement already satisfied: setuptools>=34.4.1 in /root/venv/lib/python3.7/site-packages (from cufflinks==0.17.3->-r ./requirements.txt (line 8)) (57.1.0)
# Requirement already satisfied: ipython>=5.3.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from cufflinks==0.17.3->-r ./requirements.txt (line 8)) (7.25.0)
# Collecting ipywidgets>=7.0.0
#   Downloading ipywidgets-7.6.3-py2.py3-none-any.whl (121 kB)
# Requirement already satisfied: traitlets>=4.2 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipython>=5.3.0->cufflinks==0.17.3->-r ./requirements.txt (line 8)) (5.0.5)
# Requirement already satisfied: matplotlib-inline in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipython>=5.3.0->cufflinks==0.17.3->-r ./requirements.txt (line 8)) (0.1.2)
# Requirement already satisfied: pickleshare in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipython>=5.3.0->cufflinks==0.17.3->-r ./requirements.txt (line 8)) (0.7.5)
# Requirement already satisfied: decorator in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipython>=5.3.0->cufflinks==0.17.3->-r ./requirements.txt (line 8)) (5.0.9)
# Requirement already satisfied: backcall in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipython>=5.3.0->cufflinks==0.17.3->-r ./requirements.txt (line 8)) (0.2.0)
# Requirement already satisfied: jedi>=0.16 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipython>=5.3.0->cufflinks==0.17.3->-r ./requirements.txt (line 8)) (0.17.2)
# Requirement already satisfied: pexpect>4.3 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipython>=5.3.0->cufflinks==0.17.3->-r ./requirements.txt (line 8)) (4.8.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipython>=5.3.0->cufflinks==0.17.3->-r ./requirements.txt (line 8)) (3.0.19)
# Requirement already satisfied: pygments in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipython>=5.3.0->cufflinks==0.17.3->-r ./requirements.txt (line 8)) (2.9.0)
# Collecting jupyterlab-widgets>=1.0.0
#   Downloading jupyterlab_widgets-1.0.0-py3-none-any.whl (243 kB)
# Collecting widgetsnbextension~=3.5.0
#   Downloading widgetsnbextension-3.5.1-py2.py3-none-any.whl (2.2 MB)
# Requirement already satisfied: nbformat>=4.2.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipywidgets>=7.0.0->cufflinks==0.17.3->-r ./requirements.txt (line 8)) (5.1.3)
# Requirement already satisfied: ipykernel>=4.5.1 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipywidgets>=7.0.0->cufflinks==0.17.3->-r ./requirements.txt (line 8)) (6.0.3)
# Requirement already satisfied: jupyter-client<7.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks==0.17.3->-r ./requirements.txt (line 8)) (6.1.12)
# Requirement already satisfied: importlib-metadata<4 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks==0.17.3->-r ./requirements.txt (line 8)) (3.10.1)
# Requirement already satisfied: tornado<7.0,>=4.2 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks==0.17.3->-r ./requirements.txt (line 8)) (6.1)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks==0.17.3->-r ./requirements.txt (line 8)) (1.4.1)
# Requirement already satisfied: typing-extensions>=3.6.4 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from importlib-metadata<4->ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks==0.17.3->-r ./requirements.txt (line 8)) (3.10.0.0)
# Requirement already satisfied: zipp>=0.5 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from importlib-metadata<4->ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks==0.17.3->-r ./requirements.txt (line 8)) (3.5.0)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from jedi>=0.16->ipython>=5.3.0->cufflinks==0.17.3->-r ./requirements.txt (line 8)) (0.7.1)
# Requirement already satisfied: jupyter-core>=4.6.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from jupyter-client<7.0->ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks==0.17.3->-r ./requirements.txt (line 8)) (4.7.1)
# Requirement already satisfied: pyzmq>=13 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from jupyter-client<7.0->ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks==0.17.3->-r ./requirements.txt (line 8)) (22.1.0)
# Requirement already satisfied: python-dateutil>=2.1 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from jupyter-client<7.0->ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks==0.17.3->-r ./requirements.txt (line 8)) (2.8.2)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->cufflinks==0.17.3->-r ./requirements.txt (line 8)) (3.2.0)
# Requirement already satisfied: ipython-genutils in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->cufflinks==0.17.3->-r ./requirements.txt (line 8)) (0.2.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->cufflinks==0.17.3->-r ./requirements.txt (line 8)) (0.18.0)
# Requirement already satisfied: attrs>=17.4.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->cufflinks==0.17.3->-r ./requirements.txt (line 8)) (21.2.0)
# Requirement already satisfied: ptyprocess>=0.5 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from pexpect>4.3->ipython>=5.3.0->cufflinks==0.17.3->-r ./requirements.txt (line 8)) (0.7.0)
# Requirement already satisfied: tenacity>=6.2.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from plotly>=4.1.1->cufflinks==0.17.3->-r ./requirements.txt (line 8)) (8.0.1)
# Requirement already satisfied: wcwidth in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.3.0->cufflinks==0.17.3->-r ./requirements.txt (line 8)) (0.2.5)
# Requirement already satisfied: notebook>=4.4.1 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks==0.17.3->-r ./requirements.txt (line 8)) (7.0.0.dev0)
# Requirement already satisfied: Send2Trash>=1.5.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks==0.17.3->-r ./requirements.txt (line 8)) (1.7.1)
# Requirement already satisfied: prometheus-client in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks==0.17.3->-r ./requirements.txt (line 8)) (0.11.0)
# Requirement already satisfied: jinja2 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks==0.17.3->-r ./requirements.txt (line 8)) (3.0.1)
# Requirement already satisfied: nbconvert in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks==0.17.3->-r ./requirements.txt (line 8)) (6.1.0)
# Requirement already satisfied: terminado>=0.8.3 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks==0.17.3->-r ./requirements.txt (line 8)) (0.10.1)
# Requirement already satisfied: argon2-cffi in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks==0.17.3->-r ./requirements.txt (line 8)) (20.1.0)
# Collecting et-xmlfile
#   Downloading et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Requirement already satisfied: cffi>=1.0.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks==0.17.3->-r ./requirements.txt (line 8)) (1.14.6)
# Requirement already satisfied: pycparser in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks==0.17.3->-r ./requirements.txt (line 8)) (2.20)
# Collecting soupsieve>1.2
#   Downloading soupsieve-2.2.1-py3-none-any.whl (33 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks==0.17.3->-r ./requirements.txt (line 8)) (2.0.1)
# Requirement already satisfied: testpath in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks==0.17.3->-r ./requirements.txt (line 8)) (0.5.0)
# Requirement already satisfied: bleach in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks==0.17.3->-r ./requirements.txt (line 8)) (3.3.1)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks==0.17.3->-r ./requirements.txt (line 8)) (0.5.3)
# Requirement already satisfied: defusedxml in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks==0.17.3->-r ./requirements.txt (line 8)) (0.7.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks==0.17.3->-r ./requirements.txt (line 8)) (1.4.3)
# Requirement already satisfied: mistune<2,>=0.8.1 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks==0.17.3->-r ./requirements.txt (line 8)) (0.8.4)
# Requirement already satisfied: entrypoints>=0.2.2 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks==0.17.3->-r ./requirements.txt (line 8)) (0.3)
# Requirement already satisfied: jupyterlab-pygments in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks==0.17.3->-r ./requirements.txt (line 8)) (0.1.2)
# Requirement already satisfied: nest-asyncio in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks==0.17.3->-r ./requirements.txt (line 8)) (1.5.1)
# Requirement already satisfied: async-generator in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks==0.17.3->-r ./requirements.txt (line 8)) (1.10)
# Requirement already satisfied: webencodings in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks==0.17.3->-r ./requirements.txt (line 8)) (0.5.1)
# Requirement already satisfied: packaging in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks==0.17.3->-r ./requirements.txt (line 8)) (21.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from packaging->bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks==0.17.3->-r ./requirements.txt (line 8)) (2.4.7)
# Building wheels for collected packages: bs4, yahoo-finance, cufflinks, import-ipynb
#   Building wheel for bs4 (setup.py): started
#   Building wheel for bs4 (setup.py): finished with status 'done'
#   Created wheel for bs4: filename=bs4-0.0.1-py3-none-any.whl size=1271 sha256=8ae272b8ed466eaec98b9090fb86f809d5519e428f246b0aed2a37968915cac7
#   Stored in directory: /root/.cache/pip/wheels/0a/9e/ba/20e5bbc1afef3a491f0b3bb74d508f99403aabe76eda2167ca
#   Building wheel for yahoo-finance (setup.py): started
#   Building wheel for yahoo-finance (setup.py): finished with status 'done'
#   Created wheel for yahoo-finance: filename=yahoo_finance-1.4.0-py3-none-any.whl size=7232 sha256=c488490f33e6ed81629fd2e40bcb8bc8b1dccd9611c48092d0733b71b2d53587
#   Stored in directory: /root/.cache/pip/wheels/74/3c/6e/504622cec9991612b9e3945fe8b375fef727854b42eb333c91
#   Building wheel for cufflinks (setup.py): started
#   Building wheel for cufflinks (setup.py): finished with status 'done'
#   Created wheel for cufflinks: filename=cufflinks-0.17.3-py3-none-any.whl size=67918 sha256=82b63d5b494185d6077b14138e8ae114580587edc6c64db7dae28e095ad1fc04
#   Stored in directory: /root/.cache/pip/wheels/e1/27/13/3fe67fa7ea7be444b831d117220b3b586b872c9acd4df480d0
#   Building wheel for import-ipynb (setup.py): started
#   Building wheel for import-ipynb (setup.py): finished with status 'done'
#   Created wheel for import-ipynb: filename=import_ipynb-0.1.3-py3-none-any.whl size=2975 sha256=ba2deacd53a217d6484b63f84e4157fdc7c6d52e20e1ff83975971c627698d92
#   Stored in directory: /root/.cache/pip/wheels/b1/5e/dc/79780689896a056199b0b9f24471e3ee184fbd816df355d5f0
# Successfully built bs4 yahoo-finance cufflinks import-ipynb
# Installing collected packages: widgetsnbextension, soupsieve, jupyterlab-widgets, simplejson, ipywidgets, et-xmlfile, colorlover, beautifulsoup4, yahoo-finance, xlrd, openpyxl, ipynb, import-ipynb, google, cufflinks, bs4
# Successfully installed beautifulsoup4-4.9.3 bs4-0.0.1 colorlover-0.3.0 cufflinks-0.17.3 et-xmlfile-1.1.0 google-3.0.0 import-ipynb-0.1.3 ipynb-0.5.1 ipywidgets-7.6.3 jupyterlab-widgets-1.0.0 openpyxl-3.0.7 simplejson-3.17.3 soupsieve-2.2.1 widgetsnbextension-3.5.1 xlrd-2.0.1 yahoo-finance-1.4.0
# WARNING: You are using pip version 21.1.3; however, version 21.2.1 is available.
# You should consider upgrading via the '/root/venv/bin/python -m pip install --upgrade pip' command.

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=aaf19c1d-a3b1-4f9b-b674-e32609e59fe1' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
